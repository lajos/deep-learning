# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# c:\dev\conda3\envs\dlnd\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:15, 1.99MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import numpy as np
import random

def subsample_words(i_words, threshold=0.05):
    unique, counts = np.unique(np.array(i_words), return_counts=True)
    counts = counts/len(i_words)
    freqs = 1-np.sqrt(threshold/counts)
    print('num word in:', len(i_words))
    print('num unique:', len(unique))
    print('counts max:',np.max(counts))
    print('counts mean:',np.mean(counts))
    print('num > thresh:',(freqs>0).sum())
    f = dict(zip(unique, freqs))
    o_words = [w for w in int_words if random.random()>f[w]]
    print('num words out:',len(o_words))
    return o_words

train_words = subsample_words(int_words, threshold=1e-5)
# Out:
# num word in: 16680599
# num unique: 63641
# counts max: 0.06363056866243233
# counts mean: 1.5713140899734453e-05
# num > thresh: 8199
# num words out: 4625774

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)
# Out:
# [44617, 10210]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %%
batcher = get_batches(train_words, 10)
for x,y in batcher:
    print(len(x))
    print(len(y))
    break
# Out:
# 48
# 48

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200  # number f embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From c:\dev\conda3\envs\dlnd\lib\site-packages\tensorflow\python\ops\nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-117-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6716 0.0371 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6213 0.0336 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5168 0.0352 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5892 0.0365 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5055 0.0322 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5307 0.0344 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5334 0.0369 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5432 0.0344 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4599 0.0341 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4169 0.0331 sec/batch
# Nearest to however: castilla, dramatized, eesti, soundness, tranquil, pickguard, sefer, guiana,
# Nearest to see: schroeder, old, excess, punts, brandauer, abbreviations, shipment, brugha,
# Nearest to would: hurling, homozygous, heroquest, odie, votes, princeps, emu, throat,
# Nearest to many: cached, additivity, biplanes, israelite, conyers, tame, aristide, lamprey,
# Nearest to had: nit, filius, lustrum, difference, dazzling, objectively, kardashev, hosius,
# Nearest to is: ballcarrier, candles, volt, elmhurst, afterthought, shipmates, elsa, planning,
# Nearest to while: heteronyms, inescapable, hotchkiss, apportioned, lay, sunil, highlight, prefixing,
# Nearest to new: arithm, thyestes, draining, saxonis, winnipeg, davids, metzger, malleability,
# Nearest to resources: benchmark, ciders, aitken, picton, thawed, repressed, materialist, hanford,
# Nearest to issue: section, axons, lawman, bhindranwale, addresses, salamander, yog, pant,
# Nearest to existence: donizetti, clans, food, catacomb, conceded, daffy, glencoe, founder,
# Nearest to brother: refounded, sid, testimonials, euwe, alimentary, dunham, waldseem, nonconfirmative,
# Nearest to dr: jannah, decorate, zahra, choosing, irreducible, leahy, logrus, anointed,
# Nearest to articles: evidences, birthdate, bookshop, licence, choy, introns, cody, trenton,
# Nearest to applied: impartiality, sp, mark, chile, point, questionable, treads, churchill,
# Nearest to bible: intelligentsia, talon, amdahl, ariosto, forgiveness, vu, nasrallah, kzinti,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4696 0.0350 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3753 0.0351 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3285 0.0365 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2515 0.0347 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1750 0.0346 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1724 0.0342 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1088 0.0349 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0635 0.0353 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0046 0.0335 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9698 0.0345 sec/batch
# Nearest to however: did, soundness, raster, processed, siro, resemble, pickguard, refusal,
# Nearest to see: excess, old, schroeder, abbreviations, punts, chevrolet, brugha, brandauer,
# Nearest to would: hurling, votes, hitter, able, rom, directly, gods, throat,
# Nearest to many: cached, tame, gene, term, attorney, additivity, lacked, israelite,
# Nearest to had: difference, image, nit, chalmers, predict, name, dazzling, kardashev,
# Nearest to is: planning, problem, candles, formally, piece, voted, legates, changed,
# Nearest to while: lay, heteronyms, highlight, hotchkiss, culture, maker, inescapable, psychoanalysis,
# Nearest to new: therefore, thyestes, draining, winnipeg, arithm, objectives, widely, gangs,
# Nearest to resources: benchmark, aitken, report, forum, american, picton, inhospitable, ciders,
# Nearest to issue: section, addresses, axons, tamil, budget, causing, bhindranwale, yog,
# Nearest to existence: food, although, donizetti, clans, conceded, dive, founder, applying,
# Nearest to brother: sid, refounded, specially, primo, qi, furs, testimonials, superficial,
# Nearest to dr: decorate, choosing, jannah, place, anointed, zahra, campaign, vibrato,
# Nearest to articles: licence, bookshop, birthdate, choy, evidences, doesn, almoravides, judgements,
# Nearest to applied: point, mark, less, impartiality, questionable, chile, churchill, ask,
# Nearest to bible: intelligentsia, talon, ariosto, forgiveness, referenced, divorce, shielded, webmineral,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9225 0.0364 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8800 0.0340 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8768 0.0316 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8609 0.0337 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8143 0.0345 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8091 0.0347 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7826 0.0326 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7782 0.0327 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7622 0.0356 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7798 0.0336 sec/batch
# Nearest to however: soundness, raster, hire, guiana, pickguard, castilla, ejaculation, refusal,
# Nearest to see: schroeder, abbreviations, excess, old, chevrolet, shipment, punts, brugha,
# Nearest to would: hurling, gods, votes, throat, ellis, emu, princeps, manifesting,
# Nearest to many: cached, tame, biplanes, gene, lacked, attorney, additivity, traveled,
# Nearest to had: nit, difference, snake, dazzling, kardashev, filius, image, lustrum,
# Nearest to is: legates, volt, planning, universes, candles, problem, oscillator, barriers,
# Nearest to while: heteronyms, inescapable, hotchkiss, maker, lay, highlight, psychoanalysis, culture,
# Nearest to new: thyestes, arithm, therefore, winnipeg, draining, gangs, objectives, squaring,
# Nearest to resources: benchmark, forum, report, aitken, jurisdiction, formats, thawed, stemming,
# Nearest to issue: section, addresses, axons, tamil, bhindranwale, budget, lawman, gunpowder,
# Nearest to existence: conceded, clans, food, donizetti, although, consolidate, applying, dive,
# Nearest to brother: sid, specially, primo, refounded, qi, nazism, testimonials, furs,
# Nearest to dr: decorate, choosing, campaign, jannah, zahra, anointed, place, vibrato,
# Nearest to articles: licence, evidences, birthdate, bookshop, choy, doesn, wednesday, probabilities,
# Nearest to applied: impartiality, mark, point, churchill, sp, promoting, questionable, less,
# Nearest to bible: intelligentsia, talon, forgiveness, divorce, referenced, ariosto, webmineral, north,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7884 0.0343 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7403 0.0338 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7196 0.0336 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7100 0.0344 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7546 0.0352 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7281 0.0359 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6940 0.0348 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7175 0.0337 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6724 0.0318 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6672 0.0329 sec/batch
# Nearest to however: dramatized, soundness, hire, raster, pickguard, guiana, castilla, resemble,
# Nearest to see: abbreviations, excess, schroeder, brandauer, brugha, chevrolet, punts, perishable,
# Nearest to would: hurling, gods, manifesting, votes, princeps, homozygous, odie, throat,
# Nearest to many: cached, biplanes, tame, additivity, conyers, lacked, attorney, gene,
# Nearest to had: snake, nit, filius, dazzling, kardashev, agitated, lustrum, difference,
# Nearest to is: oscillator, legates, universes, candles, barriers, topological, volt, cobalt,
# Nearest to while: heteronyms, inescapable, hotchkiss, maker, highlight, apportioned, culture, lay,
# Nearest to new: thyestes, arithm, oysters, chaney, gangs, regicides, objectives, chicago,
# Nearest to resources: benchmark, materialist, report, ciders, thawed, stemming, keying, assembles,
# Nearest to issue: section, addresses, axons, tamil, bhindranwale, lawman, tiled, seki,
# Nearest to existence: conceded, clans, donizetti, airfields, food, although, gee, catacomb,
# Nearest to brother: refounded, nazism, primo, sid, winchester, qi, shiva, uranus,
# Nearest to dr: campaign, anointed, decorate, leahy, sailor, choosing, conveying, zahra,
# Nearest to articles: birthdate, evidences, licence, bookshop, mojo, choy, wednesday, reciprocals,
# Nearest to applied: impartiality, mark, sp, churchill, point, factory, less, promoting,
# Nearest to bible: intelligentsia, talon, ariosto, forgiveness, divorce, dependency, leanings, north,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6724 0.0364 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6590 0.0349 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6112 0.0329 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6471 0.0321 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6316 0.0352 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6373 0.0340 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6124 0.0254 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5509 0.0336 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5405 0.0338 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4869 0.0320 sec/batch
# Nearest to however: dramatized, soundness, pickguard, hire, raster, guiana, ejaculation, resemble,
# Nearest to see: abbreviations, schroeder, brandauer, excess, brugha, chevrolet, perishable, proudhon,
# Nearest to would: hurling, gods, homozygous, princeps, manifesting, odie, throat, able,
# Nearest to many: cached, biplanes, additivity, term, tame, conyers, attorney, gene,
# Nearest to had: filius, nit, dazzling, snake, hiker, canary, kardashev, adulthood,
# Nearest to is: legates, universes, oscillator, candles, topological, barriers, shipmates, cleanup,
# Nearest to while: heteronyms, apportioned, inescapable, hotchkiss, maker, culture, highlight, prefixing,
# Nearest to new: thyestes, oysters, arithm, chicago, chaney, regicides, apologists, winnipeg,
# Nearest to resources: benchmark, thawed, ciders, report, assembles, keying, censors, repressed,
# Nearest to issue: section, tamil, bhindranwale, axons, addresses, lawman, tiled, seki,
# Nearest to existence: clans, conceded, donizetti, applying, gee, airfields, although, forgiveness,
# Nearest to brother: refounded, nazism, primo, uranus, mayhew, furs, winchester, dunham,
# Nearest to dr: campaign, arkham, anointed, leahy, conveying, zahra, sailor, sloth,
# Nearest to articles: birthdate, evidences, bookshop, mojo, licence, avatars, choy, reciprocals,
# Nearest to applied: impartiality, sp, churchill, mark, point, less, questionable, promoting,
# Nearest to bible: talon, intelligentsia, ariosto, forgiveness, divorce, webmineral, diss, vu,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5076 0.0343 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4806 0.0346 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4473 0.0354 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5479 0.0344 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4975 0.0340 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4525 0.0356 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4826 0.0335 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4101 0.0331 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4217 0.0324 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4302 0.0318 sec/batch
# Nearest to however: dramatized, soundness, hire, raster, did, pickguard, lansdowne, differentiates,
# Nearest to see: abbreviations, schroeder, proudhon, chevrolet, excess, brandauer, brugha, perishable,
# Nearest to would: hurling, gods, manifesting, homozygous, able, odie, votes, princeps,
# Nearest to many: cached, biplanes, additivity, tame, term, conyers, battalions, sufficient,
# Nearest to had: dazzling, filius, nit, snake, lustrum, adulthood, hiker, canary,
# Nearest to is: topological, problem, universes, legates, oscillator, constants, cobalt, candles,
# Nearest to while: heteronyms, apportioned, inescapable, hotchkiss, maker, highlight, lay, prefixing,
# Nearest to new: thyestes, chicago, chaney, oysters, arithm, winnipeg, regicides, zionist,
# Nearest to resources: benchmark, thawed, ciders, report, keying, contemplative, assembles, monomeric,
# Nearest to issue: section, tamil, addresses, bhindranwale, axons, lawman, seki, pant,
# Nearest to existence: applying, clans, conceded, donizetti, forgiveness, airfields, formalize, catacomb,
# Nearest to brother: refounded, nazism, tithes, primo, mayhew, winchester, dunham, sid,
# Nearest to dr: campaign, anointed, arkham, sloth, leahy, sailor, zahra, pennington,
# Nearest to articles: birthdate, evidences, licence, avatars, bookshop, mojo, reciprocals, choy,
# Nearest to applied: sp, impartiality, point, mark, brightness, churchill, biophysics, questionable,
# Nearest to bible: talon, prophets, ariosto, book, forgiveness, intelligentsia, divorce, prophet,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4289 0.0325 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4108 0.0320 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4450 0.0318 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3924 0.0334 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4164 0.0304 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4433 0.0325 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3879 0.0311 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3863 0.0318 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4009 0.0321 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3569 0.0309 sec/batch
# Nearest to however: dramatized, soundness, inductive, lansdowne, pickguard, did, cynics, hire,
# Nearest to see: abbreviations, schroeder, modernist, chevrolet, proudhon, brandauer, old, brugha,
# Nearest to would: hurling, gods, votes, manifesting, able, throat, homozygous, princeps,
# Nearest to many: cached, biplanes, tame, additivity, term, gene, advertisement, sufficient,
# Nearest to had: dazzling, filius, nit, snake, adulthood, met, camden, hiker,
# Nearest to is: constants, universes, legates, topological, problem, volt, metastable, diameter,
# Nearest to while: heteronyms, inescapable, hotchkiss, apportioned, highlight, maker, prefixing, lay,
# Nearest to new: chicago, thyestes, chaney, winnipeg, oysters, zionist, arithm, congress,
# Nearest to resources: benchmark, ciders, report, keying, forum, thawed, mughals, recovery,
# Nearest to issue: section, addresses, tamil, bhindranwale, axons, lawman, pallavas, seki,
# Nearest to existence: applying, clans, conceded, donizetti, forgiveness, catacomb, airfields, gee,
# Nearest to brother: refounded, tithes, shiva, nazism, mayhew, dunham, ksi, winchester,
# Nearest to dr: arkham, anointed, leahy, sailor, campaign, pennington, sloth, entertainers,
# Nearest to articles: birthdate, evidences, avatars, mojo, licence, reciprocals, bookshop, choy,
# Nearest to applied: impartiality, point, sp, mark, brightness, expansion, biophysics, gradient,
# Nearest to bible: prophets, talon, book, prophet, forgiveness, ariosto, intelligentsia, divorce,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3641 0.0335 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3811 0.0304 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3341 0.0313 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3512 0.0330 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4047 0.0303 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3611 0.0320 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3764 0.0327 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3851 0.0325 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3270 0.0308 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3200 0.0323 sec/batch
# Nearest to however: dramatized, soundness, lansdowne, hire, cynics, favoured, raster, differentiates,
# Nearest to see: abbreviations, schroeder, fj, chevrolet, brandauer, proudhon, modernist, cv,
# Nearest to would: hurling, gods, votes, snedden, able, homozygous, manifesting, throat,
# Nearest to many: biplanes, cached, advertisement, tame, term, cultural, additivity, stratigraphy,
# Nearest to had: dazzling, filius, sought, met, nit, snake, adulthood, lustrum,
# Nearest to is: legates, constants, universes, metastable, candles, volt, codons, oscillator,
# Nearest to while: heteronyms, hotchkiss, apportioned, inescapable, highlight, maker, prefixing, lay,
# Nearest to new: chicago, winnipeg, arithm, chaney, saxonis, thyestes, zionist, regicides,
# Nearest to resources: benchmark, report, forum, ciders, mughals, keying, thawed, censors,
# Nearest to issue: section, tamil, bhindranwale, addresses, axons, lawman, sennacherib, pant,
# Nearest to existence: conceded, applying, clans, donizetti, catacomb, forgiveness, embodiment, gee,
# Nearest to brother: refounded, shiva, tithes, nazism, dunham, mayhew, ksi, uranus,
# Nearest to dr: arkham, leahy, sailor, sloth, anointed, pennington, conveying, parton,
# Nearest to articles: birthdate, avatars, evidences, licence, mojo, reciprocals, choy, bookshop,
# Nearest to applied: impartiality, point, mark, sp, gradient, transformer, treads, bjp,
# Nearest to bible: prophets, prophet, book, talon, forgiveness, christian, luke, ariosto,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3424 0.0347 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3119 0.0316 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3899 0.0316 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3716 0.0302 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3984 0.0301 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2822 0.0300 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2914 0.0305 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3423 0.0304 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2451 0.0305 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2800 0.0304 sec/batch
# Nearest to however: dramatized, lansdowne, cynics, soundness, hire, pickguard, favoured, pay,
# Nearest to see: abbreviations, schroeder, frenetic, penal, cv, fj, proudhon, punts,
# Nearest to would: hurling, gods, votes, able, manifesting, homozygous, crass, odie,
# Nearest to many: biplanes, cached, tame, advertisement, cultural, term, additivity, stratigraphy,
# Nearest to had: filius, dazzling, snake, nit, lustrum, adulthood, camden, musica,
# Nearest to is: legates, constants, volt, metastable, commonality, leif, candles, symplectic,
# Nearest to while: hotchkiss, heteronyms, apportioned, inescapable, maker, highlight, lay, prefixing,
# Nearest to new: chicago, winnipeg, arithm, chaney, regicides, marathon, thyestes, ingham,
# Nearest to resources: benchmark, report, ciders, forum, metamorphic, irrigation, mughals, kashmiri,
# Nearest to issue: section, tamil, bhindranwale, addresses, seditious, seki, butlerian, lawman,
# Nearest to existence: clans, applying, conceded, formalize, donizetti, gee, catacomb, forgiveness,
# Nearest to brother: refounded, shiva, tithes, mayhew, dunham, nazism, ksi, primo,
# Nearest to dr: arkham, leahy, sailor, pennington, sloth, phineus, parton, anointed,
# Nearest to articles: birthdate, avatars, evidences, mojo, licence, bookshop, choy, reciprocals,
# Nearest to applied: impartiality, point, biophysics, gradient, sp, brightness, mark, transformer,
# Nearest to bible: prophets, book, prophet, talon, forgiveness, torah, christian, ariosto,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2983 0.0310 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2934 0.0300 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3374 0.0153 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2410 0.0298 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2341 0.0298 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2048 0.0300 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1992 0.0299 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1865 0.0298 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2039 0.0299 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1827 0.0299 sec/batch
# Nearest to however: dramatized, cynics, pickguard, soundness, lansdowne, did, hydrogens, curvilinear,
# Nearest to see: abbreviations, penal, schroeder, cv, fj, old, belarusian, proudhon,
# Nearest to would: hurling, gods, votes, homozygous, able, manifesting, crass, odie,
# Nearest to many: biplanes, cached, advertisement, term, cultural, tame, stratigraphy, whichever,
# Nearest to had: filius, dazzling, adulthood, camden, musica, snake, nit, kebir,
# Nearest to is: legates, symplectic, metastable, leif, codons, candles, commonality, universes,
# Nearest to while: heteronyms, hotchkiss, apportioned, inescapable, highlight, maker, lay, burdensome,
# Nearest to new: chicago, winnipeg, chaney, zionist, arithm, ingham, thyestes, navigated,
# Nearest to resources: benchmark, report, forum, ciders, irrigation, jurisdiction, metamorphic, vermiculite,
# Nearest to issue: section, tamil, bhindranwale, seditious, addresses, seki, lawman, butlerian,
# Nearest to existence: applying, formalize, conceded, forgiveness, clans, rejects, donizetti, embodiment,
# Nearest to brother: refounded, shiva, tithes, nazism, banished, mayhew, winchester, dunham,
# Nearest to dr: arkham, sloth, pennington, leahy, sailor, anointed, campaign, phineus,
# Nearest to articles: evidences, birthdate, avatars, portals, mojo, translated, choy, licence,
# Nearest to applied: impartiality, sp, mark, biophysics, brightness, promoting, churchill, tabular,
# Nearest to bible: prophets, book, prophet, talon, forgiveness, luke, ariosto, torah,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2590 0.0308 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2107 0.0297 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2319 0.0298 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1368 0.0300 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1904 0.0298 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1729 0.0299 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1601 0.0298 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1824 0.0300 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2191 0.0299 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1842 0.0299 sec/batch
# Nearest to however: cynics, hydrogens, soundness, dramatized, pickguard, lansdowne, favoured, pay,
# Nearest to see: abbreviations, schroeder, old, meanings, dictionaries, penal, fj, proudhon,
# Nearest to would: hurling, able, gods, votes, manifesting, homozygous, already, behaves,
# Nearest to many: cached, biplanes, advertisement, tame, cultural, term, additivity, stratigraphy,
# Nearest to had: camden, lustrum, filius, snake, musica, met, adulthood, dazzling,
# Nearest to is: symplectic, metastable, constants, asymmetry, legates, epsilon, diaeresis, codons,
# Nearest to while: heteronyms, hotchkiss, inescapable, apportioned, highlight, maker, prefixing, livelihoods,
# Nearest to new: chicago, chaney, winnipeg, zionist, jersey, regicides, arithm, navigated,
# Nearest to resources: benchmark, report, forum, ciders, jurisdiction, metamorphic, kashmiri, harmattan,
# Nearest to issue: section, bhindranwale, addresses, tamil, seki, seditious, shapeshifting, corbat,
# Nearest to existence: conceded, formalize, forgiveness, applying, catacomb, reply, rejects, donizetti,
# Nearest to brother: shiva, tithes, refounded, dunham, mayhew, banished, ksi, winchester,
# Nearest to dr: arkham, pennington, sailor, sloth, leahy, parton, anointed, yala,
# Nearest to articles: avatars, evidences, birthdate, portals, translated, bookshop, mojo, choy,
# Nearest to applied: impartiality, sp, biophysics, point, brightness, gradient, cdma, promoting,
# Nearest to bible: prophets, book, forgiveness, talon, prophet, luke, ariosto, isaiah,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1827 0.0307 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2442 0.0299 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1949 0.0301 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1534 0.0298 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1771 0.0299 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1901 0.0299 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2191 0.0301 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1517 0.0298 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1242 0.0298 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1736 0.0298 sec/batch
# Nearest to however: cynics, soundness, lansdowne, hydrogens, favoured, dramatized, differentiates, haredim,
# Nearest to see: abbreviations, schroeder, links, dictionaries, old, meanings, sk, www,
# Nearest to would: hurling, able, gods, votes, manifesting, homozygous, odie, technological,
# Nearest to many: cached, tame, advertisement, biplanes, cultural, additivity, aldus, term,
# Nearest to had: filius, camden, met, adulthood, snake, dazzling, lustrum, musica,
# Nearest to is: symplectic, legates, are, asymmetry, metastable, constants, leif, diaeresis,
# Nearest to while: inescapable, heteronyms, maker, highlight, apportioned, hotchkiss, prefixing, lay,
# Nearest to new: chicago, chaney, winnipeg, zionist, ingham, regicides, provoked, ortelius,
# Nearest to resources: benchmark, report, forum, jurisdiction, ciders, harmattan, draconis, cnidarians,
# Nearest to issue: section, bhindranwale, addresses, tamil, anthropologist, corbat, seki, enver,
# Nearest to existence: formalize, applying, conceded, crioulo, forgiveness, clans, catacomb, rejects,
# Nearest to brother: tithes, shiva, refounded, dunham, banished, ksi, discontented, mayhew,
# Nearest to dr: arkham, pennington, leahy, yala, sloth, parton, anointed, sailor,
# Nearest to articles: birthdate, avatars, evidences, portals, wiki, mojo, translated, choy,
# Nearest to applied: impartiality, biophysics, promoting, point, gradient, crick, mark, terms,
# Nearest to bible: prophets, book, forgiveness, talon, prophet, luke, isaiah, ariosto,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2105 0.0307 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1751 0.0303 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1625 0.0298 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1761 0.0300 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1451 0.0302 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1552 0.0298 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1889 0.0299 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1358 0.0300 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2127 0.0299 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2017 0.0298 sec/batch
# Nearest to however: cynics, favoured, dramatized, lansdowne, haredim, hydrogens, hire, soundness,
# Nearest to see: abbreviations, old, links, cv, fj, nizam, sk, rosicrucians,
# Nearest to would: hurling, able, votes, gods, homozygous, already, manifesting, odie,
# Nearest to many: cached, tame, advertisement, biplanes, cultural, aristide, sexy, aldus,
# Nearest to had: filius, camden, met, adulthood, lustrum, kebir, spenser, snake,
# Nearest to is: leif, legates, diaeresis, nyman, symplectic, laugh, entity, are,
# Nearest to while: heteronyms, apportioned, inescapable, hotchkiss, highlight, maker, lay, livelihoods,
# Nearest to new: chicago, chaney, winnipeg, ingham, parkman, jersey, regicides, zionist,
# Nearest to resources: benchmark, report, forum, harmattan, kashmiri, jurisdiction, materialist, cnidarians,
# Nearest to issue: section, bhindranwale, tamil, addresses, sennacherib, seki, seditious, shapeshifting,
# Nearest to existence: formalize, crioulo, applying, conceded, forgiveness, neuropsychology, gee, catacomb,
# Nearest to brother: refounded, shiva, tithes, dunham, banished, ksi, discontented, mayhew,
# Nearest to dr: arkham, pennington, sloth, leahy, parton, anointed, campaign, sailor,
# Nearest to articles: birthdate, avatars, evidences, portals, mojo, wiki, bookshop, choy,
# Nearest to applied: impartiality, biophysics, promoting, crick, tabular, churchill, point, image,
# Nearest to bible: prophets, book, forgiveness, talon, ariosto, prophet, nasrallah, thro,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2225 0.0309 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1521 0.0300 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1258 0.0299 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1323 0.0298 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0503 0.0299 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1196 0.0300 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1493 0.0298 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1419 0.0298 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1771 0.0077 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1260 0.0299 sec/batch
# Nearest to however: cynics, dramatized, favoured, haredim, lansdowne, hydrogens, tranquil, hire,
# Nearest to see: abbreviations, links, cv, sk, old, topics, rosicrucians, fj,
# Nearest to would: hurling, able, gods, homozygous, votes, already, behaves, lowers,
# Nearest to many: cached, advertisement, cultural, tame, biplanes, gardeners, often, term,
# Nearest to had: filius, met, adulthood, camden, lustrum, paragon, kebir, precipice,
# Nearest to is: leif, laugh, nyman, entity, symplectic, barriers, halts, are,
# Nearest to while: heteronyms, inescapable, apportioned, maker, hotchkiss, highlight, mtu, burdensome,
# Nearest to new: chicago, winnipeg, ingham, chaney, msdn, zionist, navigated, provoked,
# Nearest to resources: benchmark, report, forum, harmattan, kashmiri, draconis, vermiculite, materialist,
# Nearest to issue: section, bhindranwale, tamil, addresses, anthropologist, seditious, seki, passports,
# Nearest to existence: crioulo, applying, clans, formalize, gee, neuropsychology, conceded, integrable,
# Nearest to brother: refounded, tithes, shiva, banished, dunham, ksi, veneziano, norwegians,
# Nearest to dr: arkham, pennington, sloth, leahy, parton, yala, campaign, topic,
# Nearest to articles: portals, avatars, birthdate, evidences, wiki, bookshop, mojo, translated,
# Nearest to applied: impartiality, biophysics, promoting, cdma, tabular, gradient, gearbox, crick,
# Nearest to bible: prophets, book, forgiveness, talon, nasrallah, ariosto, thro, prophet,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0566 0.0307 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0646 0.0300 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1027 0.0299 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0678 0.0297 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0764 0.0299 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0188 0.0300 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0854 0.0298 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0759 0.0299 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0942 0.0299 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0068 0.0299 sec/batch
# Nearest to however: cynics, favoured, haredim, dramatized, lansdowne, hydrogens, did, soundness,
# Nearest to see: abbreviations, links, cv, old, topics, sk, dictionaries, www,
# Nearest to would: hurling, able, votes, gods, already, homozygous, mci, demilitarization,
# Nearest to many: cached, cultural, advertisement, tame, gardeners, choking, often, term,
# Nearest to had: met, kebir, filius, camden, adulthood, precipice, spenser, lustrum,
# Nearest to is: are, leif, laugh, symplectic, nyman, halts, formally, each,
# Nearest to while: heteronyms, apportioned, maker, inescapable, hotchkiss, highlight, lay, burdensome,
# Nearest to new: chicago, chaney, ingham, zionist, winnipeg, provoked, holiest, msdn,
# Nearest to resources: benchmark, forum, report, harmattan, vermiculite, alarming, kashmiri, cnidarians,
# Nearest to issue: section, bhindranwale, addresses, seditious, tamil, anthropologist, seki, gallup,
# Nearest to existence: crioulo, neuropsychology, rejects, formalize, applying, conceded, clans, gee,
# Nearest to brother: tithes, refounded, banished, shiva, dunham, ksi, veneziano, norwegians,
# Nearest to dr: arkham, pennington, sloth, leahy, campaign, anointed, yala, parton,
# Nearest to articles: portals, evidences, birthdate, avatars, wiki, bookshop, translated, mojo,
# Nearest to applied: impartiality, biophysics, promoting, cdma, copyists, tabular, crick, gradient,
# Nearest to bible: book, prophets, forgiveness, epistle, talon, bibles, ariosto, torah,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0362 0.0308 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0111 0.0301 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0194 0.0302 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0740 0.0300 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0532 0.0299 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0806 0.0303 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0637 0.0309 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1367 0.0301 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0497 0.0300 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0687 0.0299 sec/batch
# Nearest to however: cynics, hydrogens, favoured, haredim, lansdowne, soundness, dramatized, not,
# Nearest to see: abbreviations, links, topics, fj, dictionaries, rosicrucians, old, sk,
# Nearest to would: hurling, able, homozygous, gods, votes, behaves, already, manifesting,
# Nearest to many: cached, tame, advertisement, gardeners, additivity, cultural, profound, choking,
# Nearest to had: met, adulthood, camden, spenser, kebir, filius, turned, musica,
# Nearest to is: are, formally, halts, symplectic, leif, entity, laugh, a,
# Nearest to while: heteronyms, maker, inescapable, highlight, apportioned, hotchkiss, burdensome, lay,
# Nearest to new: chicago, chaney, winnipeg, ingham, zionist, holiest, msdn, dawkins,
# Nearest to resources: benchmark, forum, report, vermiculite, harmattan, methods, cnidarians, alarming,
# Nearest to issue: section, bhindranwale, addresses, passports, seditious, gallup, seki, appeasement,
# Nearest to existence: applying, crioulo, neuropsychology, formalize, reply, intuitive, integrable, rejects,
# Nearest to brother: refounded, tithes, shiva, dunham, banished, ksi, theodora, veneziano,
# Nearest to dr: arkham, pennington, parton, sloth, leahy, yala, gorgeous, campaign,
# Nearest to articles: portals, birthdate, wiki, evidences, avatars, bookshop, translated, mojo,
# Nearest to applied: impartiality, biophysics, promoting, cdma, point, gearbox, tabular, churchill,
# Nearest to bible: book, prophets, forgiveness, talon, bibles, epistle, thro, nasrallah,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0659 0.0309 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0723 0.0300 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0736 0.0304 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0379 0.0304 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0604 0.0301 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0370 0.0298 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0868 0.0299 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0693 0.0299 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1078 0.0297 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0857 0.0301 sec/batch
# Nearest to however: haredim, favoured, cynics, not, hydrogens, dramatized, lansdowne, ottomans,
# Nearest to see: links, abbreviations, fj, sk, topics, rosicrucians, nizam, cv,
# Nearest to would: hurling, able, gods, votes, homozygous, already, confessio, snedden,
# Nearest to many: advertisement, cultural, cached, tame, syncretic, profound, gardeners, additivity,
# Nearest to had: met, kebir, adulthood, spenser, filius, turned, camden, after,
# Nearest to is: laugh, are, halts, leif, symplectic, mol, mcclory, nyman,
# Nearest to while: heteronyms, maker, inescapable, apportioned, highlight, hotchkiss, burdensome, mtu,
# Nearest to new: chicago, winnipeg, chaney, ingham, zionist, holiest, provoked, apologists,
# Nearest to resources: benchmark, forum, report, harmattan, alarming, lexical, methods, vermiculite,
# Nearest to issue: section, bhindranwale, addresses, passports, shapeshifting, gallup, seditious, seki,
# Nearest to existence: crioulo, gee, formalize, intuitive, integrable, neuropsychology, clans, conceded,
# Nearest to brother: refounded, banished, ksi, veneziano, tithes, theodora, dunham, shiva,
# Nearest to dr: pennington, arkham, sloth, parton, leahy, yala, topic, anointed,
# Nearest to articles: portals, birthdate, bookshop, wiki, evidences, avatars, mojo, mcnelly,
# Nearest to applied: impartiality, biophysics, promoting, structuralism, cdma, copyists, dada, crick,
# Nearest to bible: book, prophets, forgiveness, bibles, talon, thro, torah, epistle,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0594 0.0313 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0335 0.0300 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0314 0.0301 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0574 0.0301 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1012 0.0301 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1237 0.0301 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1299 0.0303 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0299 0.0301 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0067 0.0299 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0310 0.0303 sec/batch
# Nearest to however: haredim, favoured, cynics, dramatized, strengths, hydrogens, not, confederations,
# Nearest to see: abbreviations, links, sk, fj, cv, topics, nizam, rosicrucians,
# Nearest to would: hurling, able, gods, homozygous, votes, already, snedden, behaves,
# Nearest to many: cached, advertisement, tame, cultural, gardeners, choking, often, biplanes,
# Nearest to had: met, filius, adulthood, kebir, precipice, camden, turned, spenser,
# Nearest to is: laugh, are, halts, entity, leif, mol, symplectic, diaeresis,
# Nearest to while: maker, apportioned, heteronyms, highlight, inescapable, mtu, hotchkiss, burdensome,
# Nearest to new: chicago, chaney, ingham, winnipeg, dimebag, holiest, zionist, parkman,
# Nearest to resources: benchmark, forum, report, harmattan, alarming, kashmiri, vermiculite, coniferous,
# Nearest to issue: section, bhindranwale, addresses, seditious, passports, gallup, seki, tamil,
# Nearest to existence: crioulo, gee, formalize, reply, clans, paycheck, intuitive, conceded,
# Nearest to brother: refounded, banished, veneziano, ksi, dunham, tithes, theodora, shiva,
# Nearest to dr: arkham, sloth, pennington, anointed, parton, yala, leahy, topic,
# Nearest to articles: bookshop, birthdate, avatars, portals, evidences, wiki, mojo, mcnelly,
# Nearest to applied: impartiality, promoting, cdma, biophysics, gearbox, materials, structuralism, churchill,
# Nearest to bible: book, prophets, bibles, forgiveness, thro, isaiah, talon, epistle,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0258 0.0309 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0192 0.0300 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0420 0.0301 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0418 0.0306 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0750 0.0301 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0364 0.0303 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0127 0.0302 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9652 0.0299 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0053 0.0299 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9671 0.0300 sec/batch
# Nearest to however: haredim, cynics, favoured, did, strengths, not, dramatized, hydrogens,
# Nearest to see: links, abbreviations, fj, sk, topics, cv, rosicrucians, nizam,
# Nearest to would: hurling, homozygous, gods, able, behaves, votes, odie, technological,
# Nearest to many: cached, advertisement, gardeners, cultural, tame, often, trend, choking,
# Nearest to had: adulthood, precipice, met, filius, kebir, turned, spenser, musica,
# Nearest to is: laugh, sidearm, entity, halts, leif, does, serves, are,
# Nearest to while: apportioned, heteronyms, inescapable, highlight, maker, burdensome, hotchkiss, lay,
# Nearest to new: chicago, chaney, ingham, winnipeg, dimebag, msdn, apologists, provoked,
# Nearest to resources: benchmark, forum, report, alarming, vermiculite, lexical, resource, harmattan,
# Nearest to issue: section, bhindranwale, addresses, gallup, seditious, shapeshifting, seki, corbat,
# Nearest to existence: crioulo, clans, gee, formalize, intuitive, conceded, ungodly, neuropsychology,
# Nearest to brother: banished, refounded, theodora, tithes, veneziano, andronicus, shiva, norwegians,
# Nearest to dr: sloth, pennington, arkham, yala, anointed, leahy, parton, founds,
# Nearest to articles: portals, birthdate, bookshop, avatars, evidences, wiki, mojo, mcnelly,
# Nearest to applied: impartiality, materials, copyists, biophysics, cdma, promoting, churchill, resorting,
# Nearest to bible: book, prophets, bibles, thro, isaiah, israelite, talon, forgiveness,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9813 0.0308 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9764 0.0303 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0443 0.0300 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0343 0.0302 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0283 0.0298 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0074 0.0305 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9192 0.0299 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9401 0.0301 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9124 0.0298 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0052 0.0298 sec/batch
# Nearest to however: not, favoured, cynics, haredim, did, hydrogens, dramatized, another,
# Nearest to see: links, abbreviations, topics, fj, cv, rosicrucians, sk, old,
# Nearest to would: hurling, gods, homozygous, able, votes, behaves, lowers, already,
# Nearest to many: cached, advertisement, gardeners, choking, tame, cultural, profound, often,
# Nearest to had: precipice, adulthood, turned, met, filius, discontinued, camden, kebir,
# Nearest to is: laugh, are, sidearm, a, symplectic, serves, halts, byproducts,
# Nearest to while: heteronyms, maker, apportioned, burdensome, highlight, inescapable, hotchkiss, livelihoods,
# Nearest to new: chicago, chaney, winnipeg, ingham, dimebag, apologists, city, provoked,
# Nearest to resources: benchmark, forum, coniferous, alarming, vermiculite, metamorphic, phosphates, resource,
# Nearest to issue: section, bhindranwale, addresses, gallup, seditious, anthropologist, passports, tamil,
# Nearest to existence: reply, gee, crioulo, clans, conceded, intuitive, daffy, formalize,
# Nearest to brother: refounded, banished, ksi, veneziano, theodora, tithes, dunham, norwegians,
# Nearest to dr: pennington, sloth, anointed, arkham, yala, parton, topic, founds,
# Nearest to articles: portals, bookshop, birthdate, evidences, wiki, avatars, marketers, mcnelly,
# Nearest to applied: impartiality, materials, biophysics, cdma, promoting, image, churchill, resorting,
# Nearest to bible: book, prophets, bibles, thro, talon, forgiveness, amdahl, isaiah,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0150 0.0312 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9848 0.0299 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.0063 0.0299 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0367 0.0299 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0415 0.0304 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9526 0.0299 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0036 0.0302 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9873 0.0299 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9947 0.0304 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0151 0.0300 sec/batch
# Nearest to however: not, haredim, did, cynics, favoured, strengths, soundness, hydrogens,
# Nearest to see: links, abbreviations, fj, topics, cv, sk, rosicrucians, deutschland,
# Nearest to would: hurling, able, homozygous, gods, votes, technological, lowers, already,
# Nearest to many: advertisement, cached, gardeners, profound, cultural, choking, tame, additivity,
# Nearest to had: adulthood, met, discontinued, precipice, turned, after, filius, paragon,
# Nearest to is: are, laugh, a, formally, halts, serves, an, byproducts,
# Nearest to while: maker, heteronyms, mtu, inescapable, highlight, burdensome, apportioned, livelihoods,
# Nearest to new: chicago, chaney, ingham, winnipeg, apologists, parkman, provoked, dissenters,
# Nearest to resources: benchmark, forum, alarming, resource, coniferous, repurchase, metamorphic, vermiculite,
# Nearest to issue: section, bhindranwale, addresses, passports, gallup, anthropologist, shapeshifting, seditious,
# Nearest to existence: crioulo, gee, reply, intuitive, conceded, contingent, formalize, integrable,
# Nearest to brother: banished, refounded, ksi, theodora, veneziano, tithes, andronicus, bade,
# Nearest to dr: pennington, arkham, sloth, yala, anointed, topic, leahy, sunnyvale,
# Nearest to articles: portals, wiki, birthdate, bookshop, avatars, evidences, marketers, mcnelly,
# Nearest to applied: impartiality, biophysics, cdma, promoting, materials, admissions, churchill, reproduced,
# Nearest to bible: book, prophets, bibles, thro, forgiveness, amdahl, isaiah, nasrallah,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0060 0.0310 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9629 0.0299 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9455 0.0298 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9929 0.0304 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0338 0.0300 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0056 0.0300 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9597 0.0302 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9457 0.0302 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9684 0.0299 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0320 0.0300 sec/batch
# Nearest to however: not, haredim, favoured, strengths, cynics, confederations, did, hydrogens,
# Nearest to see: links, abbreviations, fj, topics, cv, sk, nizam, deutschland,
# Nearest to would: able, hurling, gods, homozygous, votes, luddites, technological, behaves,
# Nearest to many: advertisement, gardeners, cached, reasons, tame, trend, profound, cultural,
# Nearest to had: adulthood, met, precipice, after, turned, batavian, its, brought,
# Nearest to is: laugh, are, an, halts, sidearm, formally, the, serves,
# Nearest to while: apportioned, highlight, maker, heteronyms, mtu, huber, burdensome, inescapable,
# Nearest to new: chicago, chaney, winnipeg, dimebag, ingham, process, dissenters, apologists,
# Nearest to resources: benchmark, forum, resource, coniferous, alarming, philosophy, vermiculite, report,
# Nearest to issue: section, bhindranwale, addresses, seditious, gallup, passports, ombudsman, tamil,
# Nearest to existence: gee, crioulo, contingent, conceded, clans, intuitive, formalize, daffy,
# Nearest to brother: refounded, banished, ksi, theodora, lessons, dunham, veneziano, bade,
# Nearest to dr: sloth, arkham, pennington, anointed, yala, sunnyvale, founds, leahy,
# ...
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8341 0.0328 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8210 0.0341 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8719 0.0348 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9066 0.0302 sec/batch
# Nearest to however: not, only, haredim, another, did, hydrogens, are, during,
# Nearest to see: links, of, in, the, also, external, list, history,
# Nearest to would: able, snedden, gods, quoque, homozygous, milgram, behaves, ladykillers,
# Nearest to many: most, in, often, such, which, and, well, also,
# Nearest to had: was, after, put, been, turned, began, reached, subsequently,
# Nearest to is: a, an, of, the, are, in, as, to,
# Nearest to while: cryogenics, exhibiting, are, choking, splitting, implants, to, heteronyms,
# Nearest to new: chicago, the, crelle, process, dawkins, two, with, apologists,
# Nearest to resources: resource, forum, phosphates, benchmark, lexical, sorcery, polyanin, coniferous,
# Nearest to issue: section, reports, addresses, gallup, comics, playable, advocates, misleading,
# Nearest to existence: daffy, gee, formalize, nationhood, ungodly, reply, rejects, demented,
# Nearest to brother: father, acton, banished, bb, sister, refounded, grandfather, lessons,
# Nearest to dr: jannah, forman, anointed, gorgeous, yala, irreducible, arkham, sloth,
# Nearest to articles: portals, marketers, wiki, mojo, kael, avatars, gue, bookshop,
# Nearest to applied: cdma, apply, churchill, promoting, terms, resorting, biophysics, mathematical,
# Nearest to bible: bibles, thro, isaiah, amdahl, refund, aerobics, book, jps,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8310 0.0341 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8576 0.0325 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8762 0.0345 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8585 0.0322 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8641 0.0339 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8554 0.0333 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8366 0.0329 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8470 0.0346 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8517 0.0332 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8836 0.0337 sec/batch
# Nearest to however: not, only, haredim, are, another, during, hydrogens, did,
# Nearest to see: links, of, the, in, external, also, list, history,
# Nearest to would: able, snedden, quoque, that, to, technological, ladykillers, homozygous,
# Nearest to many: most, in, which, often, such, and, especially, reasons,
# Nearest to had: was, after, put, turned, been, later, were, its,
# Nearest to is: a, of, the, an, are, this, it, as,
# Nearest to while: are, exhibiting, choking, uppercase, most, a, cryogenics, to,
# Nearest to new: chicago, crelle, process, dissenters, eoka, dawkins, apologists, york,
# Nearest to resources: resource, forum, phosphates, benchmark, polyanin, sorcery, report, coniferous,
# Nearest to issue: section, addresses, gallup, comics, reports, playable, hasidism, dss,
# Nearest to existence: gee, daffy, ungodly, heavenly, magician, clans, imperfective, demented,
# Nearest to brother: father, banished, acton, sister, lessons, bb, grandfather, ducas,
# Nearest to dr: forman, jannah, anointed, irreducible, arkham, yala, pennington, gorgeous,
# Nearest to articles: marketers, portals, kael, mojo, wikipedia, wikitravel, wiki, avatars,
# Nearest to applied: cdma, churchill, apply, promoting, mathematical, biophysics, admissions, resorting,
# Nearest to bible: thro, bibles, isaiah, amdahl, refund, kzinti, nehemiah, aerobics,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8202 0.0353 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8156 0.0350 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8275 0.0335 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8095 0.0357 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9238 0.0331 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8398 0.0320 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9420 0.0358 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9129 0.0331 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8716 0.0342 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8163 0.0342 sec/batch
# Nearest to however: not, only, during, are, another, hydrogens, haredim, pay,
# Nearest to see: links, of, also, in, external, list, the, history,
# Nearest to would: able, snedden, that, quoque, could, gods, to, homozygous,
# Nearest to many: most, and, which, often, such, reasons, in, especially,
# Nearest to had: was, after, been, subsequently, put, its, until, were,
# Nearest to is: a, an, the, of, are, as, has, also,
# Nearest to while: choking, exhibiting, and, to, are, most, splitting, heteronyms,
# Nearest to new: chicago, dimebag, crelle, process, with, one, two, york,
# Nearest to resources: resource, phosphates, forum, sorcery, deposits, polyanin, report, coniferous,
# Nearest to issue: reports, addresses, section, gallup, playable, hasidism, comics, advocates,
# Nearest to existence: gee, ungodly, daffy, clans, nationhood, demented, formalize, repercussions,
# Nearest to brother: father, acton, banished, grandfather, ducas, lessons, sister, refounded,
# Nearest to dr: forman, jannah, anointed, irreducible, arkham, gorgeous, founds, yala,
# Nearest to articles: kael, marketers, portals, mojo, wikipedia, wikitravel, avatars, attar,
# Nearest to applied: cdma, churchill, apply, transformer, promoting, resorting, criminalized, mathematical,
# Nearest to bible: thro, bibles, isaiah, amdahl, refund, kzinti, dependency, vociferous,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8170 0.0363 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8208 0.0339 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8190 0.0341 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8566 0.0343 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8407 0.0330 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8875 0.0329 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8591 0.0251 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8532 0.0340 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8238 0.0343 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8360 0.0336 sec/batch
# Nearest to however: not, only, another, agendas, are, did, during, and,
# Nearest to see: links, also, external, of, in, list, history, the,
# Nearest to would: able, better, quoque, that, snedden, could, to, spoils,
# Nearest to many: most, such, which, often, in, reasons, and, some,
# Nearest to had: was, after, been, were, subsequently, turned, until, later,
# Nearest to is: a, an, the, as, also, it, of, in,
# Nearest to while: choking, most, exhibiting, to, are, a, heteronyms, apologists,
# Nearest to new: chicago, crelle, process, colonialism, eoka, dimebag, two, grove,
# Nearest to resources: resource, forum, phosphates, sorcery, polyanin, report, deposits, basten,
# Nearest to issue: gallup, addresses, playable, hasidism, comics, reports, section, skelter,
# Nearest to existence: gee, ungodly, daffy, nationhood, formalize, valeria, demented, magician,
# Nearest to brother: father, banished, acton, grandfather, ducas, sister, theodora, refounded,
# Nearest to dr: forman, jannah, anointed, gorgeous, yala, irreducible, immune, transuranic,
# Nearest to articles: portals, kael, mojo, marketers, wikitravel, wikipedia, attar, avatars,
# Nearest to applied: churchill, apply, cdma, transformer, gearbox, knitted, promoting, resorting,
# Nearest to bible: thro, bibles, amdahl, isaiah, refund, kzinti, vociferous, aerobics,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8152 0.0331 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8410 0.0322 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7768 0.0316 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8430 0.0312 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8522 0.0313 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8518 0.0315 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8550 0.0306 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7286 0.0300 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8268 0.0299 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7840 0.0299 sec/batch
# Nearest to however: not, only, are, to, and, during, haredim, in,
# Nearest to see: links, of, in, external, the, history, list, also,
# Nearest to would: quoque, able, better, that, snedden, gods, why, behaves,
# Nearest to many: most, in, such, and, as, often, which, the,
# Nearest to had: was, been, were, after, put, subsequently, reached, turned,
# Nearest to is: a, an, the, in, of, as, are, to,
# Nearest to while: choking, most, exhibiting, heteronyms, a, are, splitting, to,
# Nearest to new: chicago, york, one, crelle, with, grove, process, colonialism,
# Nearest to resources: resource, phosphates, forum, report, sorcery, deposits, polyanin, coniferous,
# Nearest to issue: addresses, gallup, reports, hasidism, playable, advocates, comics, americanized,
# Nearest to existence: gee, daffy, ungodly, formalize, repercussions, demented, nationhood, colonize,
# Nearest to brother: father, bb, acton, grandfather, banished, sister, pva, lessons,
# Nearest to dr: forman, jannah, anointed, gorgeous, yala, irreducible, varna, pennington,
# Nearest to articles: portals, wikitravel, marketers, kael, gue, avatars, wiki, mojo,
# Nearest to applied: apply, churchill, cdma, transformer, gramme, mathematical, admissions, promoting,
# Nearest to bible: isaiah, thro, bibles, amdahl, refund, book, kzinti, dependency,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7937 0.0309 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8522 0.0299 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8536 0.0300 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8152 0.0298 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8512 0.0297 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9103 0.0298 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8053 0.0298 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8386 0.0298 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8477 0.0299 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8294 0.0297 sec/batch
# Nearest to however: not, only, are, haredim, did, another, because, during,
# Nearest to see: links, of, in, the, also, external, history, list,
# Nearest to would: able, snedden, quoque, better, milgram, why, that, could,
# Nearest to many: most, such, in, which, often, some, and, well,
# Nearest to had: was, were, after, put, been, its, turned, later,
# Nearest to is: a, an, the, as, in, of, also, are,
# Nearest to while: choking, exhibiting, most, speedy, giraffe, heteronyms, are, cope,
# Nearest to new: chicago, york, one, two, crelle, process, with, james,
# Nearest to resources: resource, forum, phosphates, polyanin, sorcery, report, repressed, benchmark,
# Nearest to issue: addresses, gallup, skelter, advocates, playable, reports, hasidism, americanized,
# Nearest to existence: gee, daffy, nationhood, ungodly, formalize, repercussions, fossil, rustam,
# Nearest to brother: father, grandfather, bb, sister, acton, banished, younger, ducas,
# Nearest to dr: forman, jannah, anointed, yala, immune, pennington, gorgeous, varna,
# Nearest to articles: portals, wikitravel, marketers, wiki, kael, gue, mojo, book,
# Nearest to applied: churchill, cdma, apply, transformer, mathematical, admissions, gramme, promoting,
# Nearest to bible: thro, isaiah, bibles, refund, amdahl, kzinti, vociferous, forgiveness,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8358 0.0309 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8591 0.0298 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8312 0.0298 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8309 0.0299 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8403 0.0298 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8288 0.0299 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8446 0.0300 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8576 0.0300 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8230 0.0299 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8284 0.0297 sec/batch
# Nearest to however: not, only, are, to, is, there, and, because,
# Nearest to see: links, of, the, in, also, external, list, history,
# Nearest to would: able, to, better, snedden, why, that, quoque, could,
# Nearest to many: most, such, in, often, which, and, the, some,
# Nearest to had: was, been, after, were, put, subsequently, its, later,
# Nearest to is: the, an, a, as, of, in, has, are,
# Nearest to while: most, are, a, and, choking, to, speedy, the,
# Nearest to new: process, chicago, crelle, eoka, york, with, colonialism, dissenters,
# Nearest to resources: resource, phosphates, forum, polyanin, report, sorcery, benchmark, deposits,
# Nearest to issue: addresses, reports, seditious, gallup, hasidism, skelter, playable, blakey,
# Nearest to existence: gee, repercussions, nationhood, daffy, ungodly, formalize, observatory, fossil,
# Nearest to brother: father, grandfather, acton, bb, sister, banished, lessons, ducas,
# Nearest to dr: forman, jannah, anointed, varna, yala, surgical, soddy, ansgar,
# Nearest to articles: wikitravel, portals, wiki, gue, marketers, kael, encyclopaedia, wikipedia,
# Nearest to applied: churchill, cdma, apply, mathematical, transformer, criminalized, admissions, gramme,
# Nearest to bible: thro, isaiah, bibles, refund, amdahl, kzinti, tuol, forgiveness,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8695 0.0308 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7817 0.0302 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9476 0.0300 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8835 0.0297 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8932 0.0298 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8161 0.0298 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7787 0.0297 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8454 0.0299 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7664 0.0297 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8669 0.0298 sec/batch
# Nearest to however: not, only, are, to, because, and, agendas, there,
# Nearest to see: links, of, also, external, in, the, list, history,
# Nearest to would: able, that, snedden, better, to, milgram, could, why,
# Nearest to many: most, which, such, often, and, in, as, reasons,
# Nearest to had: was, been, were, after, subsequently, reached, later, put,
# Nearest to is: an, a, the, in, as, are, of, also,
# Nearest to while: choking, exhibiting, speedy, to, most, cope, are, earle,
# Nearest to new: chicago, crelle, york, eoka, with, process, dimebag, two,
# Nearest to resources: resource, phosphates, forum, polyanin, basten, report, deposits, sorcery,
# Nearest to issue: addresses, hasidism, reports, gallup, seditious, skelter, playable, blakey,
# Nearest to existence: gee, daffy, ungodly, nationhood, repercussions, formalize, heavenly, colonize,
# Nearest to brother: father, grandfather, banished, bb, sister, acton, lessons, ducas,
# Nearest to dr: forman, jannah, anointed, yala, gorgeous, varna, transuranic, soddy,
# Nearest to articles: wikitravel, portals, gue, kael, marketers, wiki, chronological, attar,
# Nearest to applied: cdma, churchill, apply, transformer, mathematical, gramme, knitted, resorting,
# Nearest to bible: thro, isaiah, bibles, amdahl, refund, kzinti, jps, dependency,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8184 0.0308 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8038 0.0298 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
    sim = similarity.eval()
    for i in range(valid_size):
        valid_word = int_to_vocab[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
            close_word = int_to_vocab[nearest[k]]
            log = '%s %s,' % (log, close_word)
        print(log)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt
# Nearest to however: not, only, because, are, agendas, did, during, haredim,
# Nearest to see: links, of, also, external, the, in, list, history,
# Nearest to would: able, that, better, to, snedden, could, milgram, daughter,
# Nearest to many: most, such, often, which, as, and, reasons, some,
# Nearest to had: was, been, were, later, after, put, reached, subsequently,
# Nearest to is: an, a, the, as, in, of, it, are,
# Nearest to while: choking, exhibiting, speedy, to, cope, most, heteronyms, splitting,
# Nearest to new: chicago, with, crelle, york, process, eoka, two, vapors,
# Nearest to resources: resource, forum, phosphates, polyanin, report, basten, sorcery, deposits,
# Nearest to issue: addresses, reports, hasidism, skelter, gallup, playable, seditious, tba,
# Nearest to existence: gee, daffy, ungodly, formalize, colonize, nationhood, anticolor, observatory,
# Nearest to brother: father, grandfather, banished, sister, acton, bb, ducas, lessons,
# Nearest to dr: forman, jannah, anointed, gorgeous, yala, transuranic, soddy, varna,
# Nearest to articles: wikitravel, portals, marketers, kael, gue, wiki, chronological, encyclopaedia,
# Nearest to applied: churchill, cdma, apply, transformer, gramme, gearbox, knitted, mathematical,
# Nearest to bible: thro, isaiah, bibles, amdahl, refund, kzinti, dependency, jps,

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
